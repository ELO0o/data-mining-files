# %% [markdown]
# * Input size does not account for duplicates
# * sequence length includes entire length
# * input dimension must be 3D
# * output dimension can be 2D or 3D

# %%
import torch
import numpy as np

# %%
input_size = 4
hidden_size = 4 #usually same as input size

# %%
"""
one-hot encoded vector for hello

h = 0
e = 1
l = 2
o = 3
"""

h = [1, 0, 0, 0]
e = [0, 1, 1, 1]
l = [0, 0, 1, 0]
o = [0, 0, 0, 1]

np_batch = np.array([[h, e, l, l, o],
                     [e, o, l, l, h],
                     [l, l, e, e, l]])

input = torch.Tensor(np_batch)


rnn = torch.nn.RNN(input_size, hidden_size) #can replace RNN with GRU or LSTM for more complex RNN
output, _status = rnn(input)

print("input dimension: ", input.dim())
print("input dimension must be 3D \n")
print("input size: ", input.size())
print("_status: ", _status)
print("output dimension can be 2D or 3D \n")
print("output dimension: ", output.dim())
print("output size: ", output.size())
# Out:
# input dimension:  3
# input dimension must be 3D
#
# input size:  torch.Size([3, 5, 4])
# _status:  tensor([[[-0.7817,  0.1050,  0.7711, -0.5876],
#          [-0.6480, -0.0625,  0.8273, -0.4369],
#          [-0.8842,  0.7255,  0.8785, -0.7290],
#          [-0.8842,  0.7255,  0.8785, -0.7290],
#          [-0.7126,  0.0373,  0.8146, -0.4919]]], grad_fn=<StackBackward0>)
# output dimension can be 2D or 3D
#
# output dimension:  3
# output size:  torch.Size([3, 5, 4])

# %% [markdown]
# #Simple RNN for 'hihello'

# %%
import torch
import torch.optim as optim
import numpy as np

# %%
#declare a character set for input
char_set = ['h', 'i', 'e', 'l', 'o']

#declare hyperparameters
input_size = len(char_set)
hidden_size = input_size

learning_rate = 0.1

# %%
#declare input and output with one-hot encoding vector
"""
character indexing
h: 0
i: 1
h: 0
e: 2
l: 3
l: 3
o: 4
"""

x_data = [[0, 1, 0, 2, 3, 3]] #hihell

#passed thru hidden state
x_one_hot = [[[1, 0, 0, 0, 0], #h
              [0, 1, 0, 0, 0], #i
              [1, 0, 0, 0, 0], #h
              [0, 0, 1, 0, 0], #e
              [0, 0, 0, 1, 0], #l
              [0, 0, 0, 1, 0]]] #l

y_data = [[1, 0, 2, 3, 3, 4]] #iello

# %%
X = torch.FloatTensor(x_one_hot)
Y = torch.LongTensor(y_data)

#batch_first returns (batch_size, sequence_length, input_size) format
rnn = torch.nn.RNN(input_size, hidden_size, batch_first=True)

#sequence length and batch size automatically found with RNN
print("input dimension: ", X.dim())
print("input dimension must be 3D \n")
print("input size: ", X.size())
print("\n output dimension can be 2D or 3D")
print("output dimension: ", Y.dim())
print("output size: ", Y.size())
# Out:
# input dimension:  3
# input dimension must be 3D
#
# input size:  torch.Size([1, 6, 5])
#
#  output dimension can be 2D or 3D
# output dimension:  2
# output size:  torch.Size([1, 6])

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.Adam(rnn.parameters(), learning_rate)

# %%
#training
for i in range(100):
  optimizer.zero_grad()
  output, _status = rnn(X)
  loss = criterion(output.view(-1, input_size), Y.view(-1))
  loss.backward()
  optimizer.step()

  result = output.data.numpy().argmax(axis=2)
  print("Result: ", result)

  result_str = ''.join([char_set[c] for c in np.squeeze(result)])
  print(i, 'loss: ', loss.item(), 'prediction: ', result, 'actual label: ', y_data, 'predicted string: ', result_str)
# Out:
# Result:  [[4 3 2 3 3 3]]
# 0 loss:  1.4657249450683594 prediction:  [[4 3 2 3 3 3]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  olelll
# Result:  [[2 3 2 3 3 3]]
# 1 loss:  1.3235732316970825 prediction:  [[2 3 2 3 3 3]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  elelll
# Result:  [[2 3 2 3 3 3]]
# 2 loss:  1.1965075731277466 prediction:  [[2 3 2 3 3 3]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  elelll
# Result:  [[2 0 2 3 3 3]]
# 3 loss:  1.0721694231033325 prediction:  [[2 0 2 3 3 3]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ehelll
# Result:  [[2 0 2 3 3 4]]
# 4 loss:  0.9572381973266602 prediction:  [[2 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ehello
# Result:  [[1 0 2 3 3 4]]
# 5 loss:  0.8644183278083801 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 6 loss:  0.794550359249115 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 7 loss:  0.7341463565826416 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 8 loss:  0.680506706237793 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 9 loss:  0.6398210525512695 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 10 loss:  0.6083447337150574 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 11 loss:  0.5781652927398682 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 12 loss:  0.5577511787414551 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 13 loss:  0.5439288020133972 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 14 loss:  0.5275223851203918 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 15 loss:  0.5203226208686829 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 16 loss:  0.5119434595108032 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 17 loss:  0.503563642501831 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 18 loss:  0.5008647441864014 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 19 loss:  0.4944900572299957 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 20 loss:  0.49156031012535095 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 21 loss:  0.48954901099205017 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 22 loss:  0.48558759689331055 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 23 loss:  0.48422619700431824 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 24 loss:  0.4821805953979492 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 25 loss:  0.47983744740486145 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 26 loss:  0.4794054329395294 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 27 loss:  0.47739335894584656 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 28 loss:  0.4765702188014984 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 29 loss:  0.4758246839046478 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 30 loss:  0.4743504226207733 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 31 loss:  0.47413840889930725 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 32 loss:  0.47277262806892395 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 33 loss:  0.4723942279815674 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 34 loss:  0.47168707847595215 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 35 loss:  0.4709808826446533 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 36 loss:  0.4707382917404175 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 37 loss:  0.4698046147823334 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 38 loss:  0.4696786403656006 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 39 loss:  0.4688854515552521 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 40 loss:  0.46863672137260437 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 41 loss:  0.4681786298751831 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 42 loss:  0.46773219108581543 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 43 loss:  0.4674915075302124 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 44 loss:  0.4669688642024994 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 45 loss:  0.4667844772338867 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 46 loss:  0.46628355979919434 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 47 loss:  0.46612295508384705 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 48 loss:  0.4657069742679596 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 49 loss:  0.46549639105796814 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 50 loss:  0.46519824862480164 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 51 loss:  0.46491310000419617 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 52 loss:  0.4646964967250824 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 53 loss:  0.46438542008399963 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 54 loss:  0.46420910954475403 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 55 loss:  0.4639129340648651 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 56 loss:  0.4637514054775238 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 57 loss:  0.4634805917739868 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 58 loss:  0.46329978108406067 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 59 loss:  0.4630686938762665 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 60 loss:  0.46286892890930176 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 61 loss:  0.46267327666282654 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 62 loss:  0.46246767044067383 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 63 loss:  0.4622946083545685 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 64 loss:  0.46208655834198 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 65 loss:  0.4619254171848297 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 66 loss:  0.46172165870666504 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 67 loss:  0.46156439185142517 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 68 loss:  0.4613725244998932 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 69 loss:  0.4612191915512085 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 70 loss:  0.46103766560554504 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 71 loss:  0.4608844220638275 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 72 loss:  0.46071240305900574 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 73 loss:  0.46055981516838074 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 74 loss:  0.4603959321975708 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 75 loss:  0.4602457582950592 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 76 loss:  0.46008965373039246 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 77 loss:  0.4599425792694092 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 78 loss:  0.4597916305065155 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 79 loss:  0.45964720845222473 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 80 loss:  0.4595007598400116 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 81 loss:  0.4593602120876312 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 82 loss:  0.4592178761959076 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 83 loss:  0.4590812027454376 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 84 loss:  0.4589426815509796 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 85 loss:  0.45880961418151855 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 86 loss:  0.4586740732192993 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 87 loss:  0.4585442543029785 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 88 loss:  0.4584120810031891 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 89 loss:  0.4582858979701996 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 90 loss:  0.4581569731235504 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 91 loss:  0.45803365111351013 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 92 loss:  0.45790812373161316 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 93 loss:  0.45778748393058777 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 94 loss:  0.45766523480415344 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 95 loss:  0.45754680037498474 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 96 loss:  0.45742833614349365 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 97 loss:  0.4573122262954712 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 98 loss:  0.4571970999240875 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
# Result:  [[1 0 2 3 3 4]]
# 99 loss:  0.4570830762386322 prediction:  [[1 0 2 3 3 4]] actual label:  [[1, 0, 2, 3, 3, 4]] predicted string:  ihello
